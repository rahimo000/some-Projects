# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import math
import numpy as np

# %%
def distance(x, y, x1, y1):   #returns float
  return math.sqrt(((x-x1)**2) + ((y-y1)**2))

# %%
#read csv file
iris_arr = pd.read_csv("iris.csv", sep=',', header=None).values
print(iris_arr)
# Out:
# [['petal_length' 'petal_width' 'species']
#  ['1.4' '0.2' '0']
#  ['1.4' '0.2' '0']
#  ['1.3' '0.2' '0']
#  ['1.5' '0.2' '0']
#  ['1.4' '0.2' '0']
#  ['1.7' '0.4' '0']
#  ['1.4' '0.3' '0']
#  ['1.5' '0.2' '0']
#  ['1.4' '0.2' '0']
#  ['1.5' '0.1' '0']
#  ['1.5' '0.2' '0']
#  ['1.6' '0.2' '0']
#  ['1.4' '0.1' '0']
#  ['1.1' '0.1' '0']
#  ['1.2' '0.2' '0']
#  ['1.5' '0.4' '0']
#  ['1.3' '0.4' '0']
#  ['1.4' '0.3' '0']
#  ['1.7' '0.3' '0']
#  ['1.5' '0.3' '0']
#  ['1.7' '0.2' '0']
#  ['1.5' '0.4' '0']
#  ['1.0' '0.2' '0']
#  ['1.7' '0.5' '0']
#  ['1.9' '0.2' '0']
#  ['1.6' '0.2' '0']
#  ['1.6' '0.4' '0']
#  ['1.5' '0.2' '0']
#  ['1.4' '0.2' '0']
#  ['1.6' '0.2' '0']
#  ['1.6' '0.2' '0']
#  ['1.5' '0.4' '0']
#  ['1.5' '0.1' '0']
#  ['1.4' '0.2' '0']
#  ['1.5' '0.1' '0']
#  ['1.2' '0.2' '0']
#  ['1.3' '0.2' '0']
#  ['1.5' '0.1' '0']
#  ['1.3' '0.2' '0']
#  ['1.5' '0.2' '0']
#  ['1.3' '0.3' '0']
#  ['1.3' '0.3' '0']
#  ['1.3' '0.2' '0']
#  ['1.6' '0.6' '0']
#  ['1.9' '0.4' '0']
# ...
